# %% [markdown]
# # Stop Words
# Words like "a" and "the" appear so frequently that they don't require tagging as thoroughly as nouns, verbs and modifiers. We call these *stop words*, and they can be filtered from the text to be processed. spaCy holds a built-in list of some 305 English stop words.

# %%
# Perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Print the set of spaCy's default stop words (remember that sets are unordered):
print(nlp.Defaults.stop_words)
# Out:
# {'became', 'the', 'say', 'thereupon', 'these', 'they', 'always', 'whole', 'her', 'whatever', 'whereupon', 'does', 'being', 'ca', '‘ve', 'either', '‘re', 'also', 'could', 'with', 'be', 'where', 'thereby', 'myself', 'on', 'nor', 'within', 'quite', 'n’t', 'two', 'ever', 'if', 'at', 'whether', 'latterly', 'when', 'call', 'into', 'already', 'that', 'him', 'however', 'see', 'bottom', 'here', 'what', 'besides', 'just', "'s", 'less', 'namely', 'give', 'same', 'meanwhile', "'m", 'among', 'it', 'he', 'done', 'out', 'their', 'about', 'n‘t', 'those', 'in', 'someone', 'twelve', 'anyway', 'anyone', 'must', 'upon', 'thus', 'though', 'a', 'to', 'was', 'due', 'otherwise', 'enough', 'sixty', 'last', 'hundred', 'third', 'sometimes', 'have', 'unless', 'please', 'beforehand', 'against', 'others', 'this', 'who', 'i', 'for', 'around', 'whom', 'none', 'toward', 'yet', 'everywhere', 'such', '‘s', 'whence', 'five', 'well', 'amount', 'himself', 'full', 'she', 'go', 'own', 'elsewhere', 'mine', 'alone', 'because', 'sometime', 'take', 'get', 'had', 'anyhow', 'while', 'nobody', 'behind', 'latter', 'next', '’d', 'something', 'my', 'whereafter', 'made', 'whenever', 'during', 'all', 'other', 'whose', 'yourself', 'thence', 'even', 'some', 'very', 'fifty', 'neither', 'four', 'his', 'hereupon', 'but', 'several', 'both', 'becoming', 'thru', 'show', 'over', 'therein', 'once', 'anything', 'did', 'each', 'further', 'name', 'amongst', 'only', 'most', 'one', 'between', 'why', 'yourselves', 'together', 'keep', 'doing', 'often', 'after', 'formerly', 'we', 'without', 'eight', 'else', 'former', 'seem', 'make', 'fifteen', 'towards', 'whereas', 'six', 'across', 'nothing', "n't", 'so', 'which', 'not', 'every', 'than', 'move', 'again', 'are', '‘m', 'still', 'no', 'empty', 'seems', 'regarding', 'them', 'hereby', 'used', 'and', 'were', 'from', 'hers', 'or', 'its', 'mostly', 'per', 'although', 'never', "'re", 'except', 'off', '’ll', 'hereafter', 'thereafter', 'until', 'herself', 'somewhere', 'nine', 'few', 'three', 'then', 'throughout', 'should', 'am', 'any', 'another', 'via', 'herein', 'wherever', 'is', 'ten', 'many', 'down', 'top', 'everyone', '‘ll', 'serious', 'much', 'seeming', 'afterwards', 'how', 'everything', 'wherein', 'through', 'first', 'cannot', 'do', 'there', 'itself', '‘d', 'onto', '’m', 'using', 'whither', 'by', 'whoever', 'seemed', 're', 'part', 'perhaps', 'too', 'various', '’ve', 'might', 'our', 'yours', 'side', "'ve", 'below', 'almost', 'us', 'before', 'now', 'becomes', 'along', 'your', 'would', 'more', 'since', 'an', 'become', 'been', 'under', 'as', 'above', 'forty', 'rather', 'of', 'front', 'twenty', "'ll", 'hence', 'back', 'put', 'up', 'moreover', 'ourselves', 'least', 'will', 'anywhere', 'indeed', 'whereby', 'you', 'beyond', 'ours', "'d", 'really', 'therefore', '’s', 'themselves', 'has', 'somehow', 'noone', 'can', 'nowhere', 'me', 'eleven', '’re', 'beside', 'may', 'nevertheless'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %% [markdown]
# ## To see if a word is a stop word

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %% [markdown]
# ## To add a stop word
# There may be times when you wish to add a stop word to the default set. Perhaps you decide that `'btw'` (common shorthand for "by the way") should be considered a stop word.

# %%
# Add the word to the set of stop words. Use lowercase!
nlp.Defaults.stop_words.add('btw')

# Set the stop_word tag on the lexeme
nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %% [markdown]
# <font color=green>When adding stop words, always use lowercase. Lexemes are converted to lowercase before being added to **vocab**.</font>

# %% [markdown]
# ## To remove a stop word
# Alternatively, you may decide that `'beyond'` should not be considered a stop word.

# %%
# Remove the word from the set of stop words
nlp.Defaults.stop_words.remove('beyond')

# Remove the stop_word tag from the lexeme
nlp.vocab['beyond'].is_stop = False

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False
