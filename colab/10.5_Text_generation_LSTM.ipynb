# %% [markdown]
# #Automatic Text Generation
#
# Automatic text generation is the generation of natural language texts by computer. It has applications in automatic documentation systems, automatic letter writing, automatic report generation, etc. In this project, we are going to generate words given a set of input words. We are going to train the LSTM model using William Shakespeare’s writings

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/lstm.png" width="1200">

# %% [markdown]
# - Long Short-Term Memory (LSTM) networks are a modified version of recurrent neural networks, which makes it easier to remember past data in memory.
# - Generally LSTM is composed of a cell (the memory part of the LSTM unit) and three “regulators”, usually called gates, of the flow of information inside the LSTM unit: an input gate, an output gate and a forget gate.
# - Intuitively, the cell is responsible for keeping track of the dependencies between the elements in the input sequence.
# - The input gate controls the extent to which a new value flows into the cell, the forget gate controls the extent to which a value remains in the cell and the output gate controls the extent to which the value in the cell is used to compute the output activation of the LSTM unit.
# - The activation function of the LSTM gates is often the logistic sigmoid function.
# - There are connections into and out of the LSTM gates, a few of which are recurrent. The weights of these connections, which need to be learned during training, determine how the gates operate

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/shakespeare2.jpg" width="1200">

# %%
# tensorflow 2.x
import tensorflow as tf
import string
import requests

import warnings
warnings.filterwarnings("ignore")

# %%
response = requests.get('https://ocw.mit.edu/ans7870/6/6.006/s08/lecturenotes/files/t8.shakespeare.txt')

# %%
#first 1500 characters
response.text[:1500]
# Out:
# 'This is the 100th Etext file presented by Project Gutenberg, and\nis presented in cooperation with World Library, Inc., from their\nLibrary of the Future and Shakespeare CDROMS.  Project Gutenberg\noften releases Etexts that are NOT placed in the Public Domain!!\n\nShakespeare\n\n*This Etext has certain copyright implications you should read!*\n\n<<THIS ELECTRONIC VERSION OF THE COMPLETE WORKS OF WILLIAM\nSHAKESPEARE IS COPYRIGHT 1990-1993 BY WORLD LIBRARY, INC., AND IS\nPROVIDED BY PROJECT GUTENBERG ETEXT OF ILLINOIS BENEDICTINE COLLEGE\nWITH PERMISSION.  ELECTRONIC AND MACHINE READABLE COPIES MAY BE\nDISTRIBUTED SO LONG AS SUCH COPIES (1) ARE FOR YOUR OR OTHERS\nPERSONAL USE ONLY, AND (2) ARE NOT DISTRIBUTED OR USED\nCOMMERCIALLY.  PROHIBITED COMMERCIAL DISTRIBUTION INCLUDES BY ANY\nSERVICE THAT CHARGES FOR DOWNLOAD TIME OR FOR MEMBERSHIP.>>\n\n*Project Gutenberg is proud to cooperate with The World Library*\nin the presentation of The Complete Works of William Shakespeare\nfor your reading for education and entertainment.  HOWEVER, THIS\nIS NEITHER SHAREWARE NOR PUBLIC DOMAIN. . .AND UNDER THE LIBRARY\nOF THE FUTURE CONDITIONS OF THIS PRESENTATION. . .NO CHARGES MAY\nBE MADE FOR *ANY* ACCESS TO THIS MATERIAL.  YOU ARE ENCOURAGED!!\nTO GIVE IT AWAY TO ANYONE YOU LIKE, BUT NO CHARGES ARE ALLOWED!!\n\n\n**Welcome To The World of Free Plain Vanilla Electronic Texts**\n\n**Etexts Readable By Both Humans and By Computers, Since 1971**\n\n*These Etexts Prepared By Hundreds of Volunteers and Donations*\n\nInforma'

# %%
#Now we are going to split the text with respect to \n.
data = response.text.split('\n')
data[0]
# Out:
# 'This is the 100th Etext file presented by Project Gutenberg, and'

# %%
#The text file contains a header file before the actual data begins. The actual data begins from line 253. So we are going to slice the data and retain everything from line 253 onwards.
data = data[253:]
data[0]
# Out:
# '  From fairest creatures we desire increase,'

# %%
# how many lines?
len(data)
# Out:
# 124204

# %%
# Now we are going to join all the lines and create a long string consisting of the data in continuous format
data = " ".join(data)
data[:1000]
# Out:
# "  From fairest creatures we desire increase,   That thereby beauty's rose might never die,   But as the riper should by time decease,   His tender heir might bear his memory:   But thou contracted to thine own bright eyes,   Feed'st thy light's flame with self-substantial fuel,   Making a famine where abundance lies,   Thy self thy foe, to thy sweet self too cruel:   Thou that art now the world's fresh ornament,   And only herald to the gaudy spring,   Within thine own bud buriest thy content,   And tender churl mak'st waste in niggarding:     Pity the world, or else this glutton be,     To eat the world's due, by the grave and thee.                        2   When forty winters shall besiege thy brow,   And dig deep trenches in thy beauty's field,   Thy youth's proud livery so gazed on now,   Will be a tattered weed of small worth held:     Then being asked, where all thy beauty lies,   Where all the treasure of thy lusty days;   To say within thine own deep sunken eyes,   Were an all"

# %%
#We are going to create a function clean_text() to remove all the punctuation marks and special characters from the data.

# %% [markdown]
# We will split the data according to space character and separate each word using split().
#
# maketrans() function is used to construct the transition table i.e specify the list of characters that need to be replaced in the whole string or the characters that need to be deleted from the string. The first parameter specifies the list of characters that need to be replaced, the second parameter specifies the list of characters with which the characters need to be replaced, the third parameter specifies the list of characters that needs to be deleted.It returns the translation table which specifies the conversions that can be used by translate().
#
# string.punctuation is a pre-initialized string used as string constant which will give all the sets of punctuation.
#
# To translate the characters in the string translate() is used to make the translations. This function uses the translation mapping specified using the maketrans().
#
# The isalpha() method returns True if all the characters are alphabet letters (a-z). The lower() methods returns the lowercased string from the given string.
#
# We can see that after passing data to clean_text() we get the data in the required format without punctuations and special characters.

# %%
def clean_text(doc):
  tokens = doc.split()
  table = str.maketrans('', '', string.punctuation)
  tokens = [w.translate(table) for w in tokens]
  tokens = [word for word in tokens if word.isalpha()]
  tokens = [word.lower() for word in tokens]
  return tokens

tokens = clean_text(data)
print(tokens[:50])
# Out:
# ['from', 'fairest', 'creatures', 'we', 'desire', 'increase', 'that', 'thereby', 'beautys', 'rose', 'might', 'never', 'die', 'but', 'as', 'the', 'riper', 'should', 'by', 'time', 'decease', 'his', 'tender', 'heir', 'might', 'bear', 'his', 'memory', 'but', 'thou', 'contracted', 'to', 'thine', 'own', 'bright', 'eyes', 'feedst', 'thy', 'lights', 'flame', 'with', 'selfsubstantial', 'fuel', 'making', 'a', 'famine', 'where', 'abundance', 'lies', 'thy']

# %%
# total tokens
len(tokens)
# Out:
# 898199

# %%
#The total number of unique words
len(set(tokens))
# Out:
# 27956

# %% [markdown]
# As discussed before we are going to use a set of previous words to predict the next word in the sentence. To be precise we are going to use a set of 50 words to predict the 51st word. Hence we are going to divide our data in chunks of 51 words and at the last we will separate the last word from every line. We are going to limit our dataset to 200000 words.

# %%
length = 50 + 1
lines = []

for i in range(length, len(tokens)):
  seq = tokens[i-length:i]
  line = ' '.join(seq)
  lines.append(line)
  if i > 200000:
    break

print(len(lines))
# Out:
# 199951

# %%
lines
# Out:
# ['from fairest creatures we desire increase that thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self',
#  'fairest creatures we desire increase that thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy',
#  'creatures we desire increase that thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe',
#  'we desire increase that thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to',
#  'desire increase that thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy',
#  'increase that thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet',
#  'that thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self',
#  'thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too',
#  'beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel',
#  'rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou',
#  'might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that',
#  'never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art',
#  'die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now',
#  'but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the',
#  'as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds',
#  'the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh',
#  'riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament',
#  'should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and',
#  'by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only',
#  'time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald',
#  'decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to',
#  'his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the',
#  'tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy',
#  'heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring',
#  'might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within',
#  'bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine',
#  'his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own',
#  'memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud',
#  'but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest',
#  'thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy',
#  'contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content',
#  'to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and',
#  'thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender',
#  'own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl',
#  'bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst',
#  'eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste',
#  'feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in',
#  'thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding',
#  'lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity',
#  'flame with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the',
#  'with selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world',
#  'selfsubstantial fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or',
#  'fuel making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else',
#  'making a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this',
#  'a famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton',
#  'famine where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be',
#  'where abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to',
#  'abundance lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat',
#  'lies thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the',
#  'thy self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds',
#  'self thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due',
#  'thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by',
#  'foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the',
#  'to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave',
#  'thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and',
#  'sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee',
#  'self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when',
#  'too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty',
#  'cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters',
#  'thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall',
#  'that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege',
#  'art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy',
#  'now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow',
#  'the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and',
#  'worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig',
#  'fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep',
#  'ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches',
#  'and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in',
#  'only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy',
#  'herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys',
#  'to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field',
#  'the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy',
#  'gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths',
#  'spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud',
#  'within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery',
#  'thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so',
#  'own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed',
#  'bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on',
#  'buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now',
#  'thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will',
#  'content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be',
#  'and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a',
#  'tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered',
#  'churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed',
#  'makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of',
#  'waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small',
#  'in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth',
#  'niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held',
#  'pity the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then',
#  'the world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being',
#  'world or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked',
#  'or else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where',
#  'else this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all',
#  'this glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy',
#  'glutton be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty',
#  'be to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies',
#  'to eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where',
#  'eat the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all',
#  'the worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the',
#  'worlds due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure',
#  'due by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of',
#  'by the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy',
#  'the grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty',
#  'grave and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days',
#  'and thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to',
#  'thee when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say',
#  'when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within',
#  'forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine',
#  'winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own',
#  'shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep',
#  'besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken',
#  'thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes',
#  'brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were',
#  'and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an',
#  'dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating',
#  'deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame',
#  'trenches in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and',
#  'in thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless',
#  'thy beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise',
#  'beautys field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how',
#  'field thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much',
#  'thy youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more',
#  'youths proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise',
#  'proud livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved',
#  'livery so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy',
#  'so gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys',
#  'gazed on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use',
#  'on now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if',
#  'now will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou',
#  'will be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst',
#  'be a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer',
#  'a tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this',
#  'tattered weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair',
#  'weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child',
#  'of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of',
#  'small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine',
#  'worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall',
#  'held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum',
#  'then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my',
#  'being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count',
#  'asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and',
#  'where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make',
#  'all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my',
#  'thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old',
#  'beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse',
#  'lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving',
#  'where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his',
#  'all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty',
#  'the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by',
#  'treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession',
#  'of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine',
#  'thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this',
#  'lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were',
#  'days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to',
#  'to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be',
#  'say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new',
#  'within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made',
#  'thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when',
#  'own deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou',
#  'deep sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art',
#  'sunken eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old',
#  'eyes were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old and',
#  'were an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old and see',
#  'an alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old and see thy',
#  'alleating shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old and see thy blood',
#  'shame and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old and see thy blood warm',
#  'and thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old and see thy blood warm when',
#  'thriftless praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old and see thy blood warm when thou',
#  'praise how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old and see thy blood warm when thou feelst',
#  'how much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old and see thy blood warm when thou feelst it',
#  'much more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old and see thy blood warm when thou feelst it cold',
#  'more praise deserved thy beautys use if thou couldst answer this fair child of mine shall sum my count and make my old excuse proving his beauty by succession thine this were to be new made when thou art old and see thy blood warm when thou feelst it cold look',
# ...
#  'but his place for still the world enjoys it but beautys waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who',
#  'his place for still the world enjoys it but beautys waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for',
#  'place for still the world enjoys it but beautys waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy',
#  'for still the world enjoys it but beautys waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self',
#  'still the world enjoys it but beautys waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art',
#  'the world enjoys it but beautys waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so',
#  'world enjoys it but beautys waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident',
#  'enjoys it but beautys waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant',
#  'it but beautys waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if',
#  'but beautys waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou',
#  'beautys waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt',
#  'waste hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou',
#  'hath in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art',
#  'in the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved',
#  'the world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of',
#  'world an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many',
#  'an end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but',
#  'end and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that',
#  'and kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou',
#  'kept unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none',
#  'unused the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst',
#  'the user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is',
#  'user so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most',
#  'so destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident',
#  'destroys it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for',
#  'it no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou',
#  'no love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art',
#  'love toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so',
#  'toward others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed',
#  'others in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with',
#  'in that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous',
#  'that bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate',
#  'bosom sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that',
#  'sits that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst',
#  'that on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy',
#  'on himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self',
#  'himself such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou',
#  'such murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst',
#  'murdrous shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not',
#  'shame commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to',
#  'commits for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire',
#  'for shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking',
#  'shame deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that',
#  'deny that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous',
#  'that thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof',
#  'thou bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to',
#  'bearst love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate',
#  'love to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate which',
#  'to any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate which to',
#  'any who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate which to repair',
#  'who for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate which to repair should',
#  'for thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate which to repair should be',
#  'thy self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate which to repair should be thy',
#  'self art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate which to repair should be thy chief',
#  'art so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate which to repair should be thy chief desire',
#  'so unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate which to repair should be thy chief desire o',
#  'unprovident grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate which to repair should be thy chief desire o change',
#  'grant if thou wilt thou art beloved of many but that thou none lovst is most evident for thou art so possessed with murdrous hate that gainst thy self thou stickst not to conspire seeking that beauteous roof to ruinate which to repair should be thy chief desire o change thy',
#  ...]

# %%
lines[0]
# Out:
# 'from fairest creatures we desire increase that thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self'

# %%
#The 51st word in this line is 'self' which will the output word used for prediction.
tokens[50]

#the 51st word in this line is 'thy' which will the output word used for prediction.
# Out:
# 'self'

# %% [markdown]
# ## Build LSTM Model and Prepare X and y

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# We are going to create a unique numerical token for each unique word in the dataset. fit_on_texts() updates internal vocabulary based on a list of texts. texts_to_sequences() transforms each text in texts to a sequence of integers.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines)
sequences = tokenizer.texts_to_sequences(lines)

# %% [markdown]
# sequences containes a list of integer values created by tokenizer. Each line in sequences has 51 words. Now we will split each line such that the first 50 words are in X and the last word is in y

# %%
sequences = np.array(sequences)
X, y = sequences[:, :-1], sequences[:,-1]
X[0]
# Out:
# array([   47,  1408,  1264,    37,   451,  1406,     9,  2766,  1158,
#         1213,   171,   132,   269,    20,    24,     1,  4782,    87,
#           30,    98,  4781,    18,   715,  1263,   171,   211,    18,
#          829,    20,    27,  3807,     4,   214,   121,  1212,   153,
#        13004,    31,  2765,  1847,    16, 13003, 13002,   754,     7,
#         3806,    99,  2430,   466,    31])

# %% [markdown]
# vocab_size contains all the uniques words in the dataset. tokenizer.word_index gives the mapping of each unique word to its numerical equivalent. Hence len() of tokenizer.word_index gives the vocab_size.

# %%
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 13009

# %% [markdown]
# to_categorical() converts a class vector (integers) to binary class matrix. num_classes is the total number of classes which is vocab_size

# %%
y = to_categorical(y, num_classes=vocab_size)

# %% [markdown]
# The length of each sequence in X is 50.

# %%
seq_length = X.shape[1]
seq_length
# Out:
# 50

# %% [markdown]
# A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor.

# %% [markdown]
# ### Embedding layer:
# The Embedding layer is initialized with random weights and will learn an embedding for all of the words in the training dataset. It requires 3 arguments:
#
# + input_dim: This is the size of the vocabulary in the text data which is vocab_size in this case.
# + output_dim: This is the size of the vector space in which words will be embedded. It defines the size of the output vectors from this layer for each word.
# + input_length: Length of input sequences which is seq_length.

# %%
model = Sequential()
model.add(Embedding(vocab_size, 50, input_length=seq_length))
model.add(LSTM(100, return_sequences=True))
model.add(LSTM(100))
model.add(Dense(100, activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))

# %% [markdown]
# ### LSTM layer:
# This is the main layer of the model. It learns long-term dependencies between time steps in time series and sequence data. return_sequence when set to True returns the full sequence as the output.
#
# ### Dense layer:
# Dense layer is the regular deeply connected neural network layer. It is the most common and frequently used layer. The rectified linear activation function or relu for short is a piecewise linear function that will output the input directly if it is positive, otherwise, it will output zero.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 50, 50)            650450
# _________________________________________________________________
# lstm (LSTM)                  (None, 50, 100)           60400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 100)               10100
# _________________________________________________________________
# dense_1 (Dense)              (None, 13009)             1313909
# =================================================================
# Total params: 2,115,259
# Trainable params: 2,115,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %% [markdown]
# fter compiling the model we will now train the model using model.fit() on the training dataset. We will use 100 epochs to train the model. An epoch is an iteration over the entire x and y data provided. batch_size is the number of samples per gradient update i.e. the weights will be updates after 256 training examples.

# %%
# %%time

model.fit(X, 
          y, 
          batch_size = 256, 
          epochs = 100) #try 250
# Out:
# Epoch 1/100
# 782/782 [==============================] - 82s 62ms/step - loss: 7.2068 - accuracy: 0.0280
# Epoch 2/100
# 782/782 [==============================] - 47s 60ms/step - loss: 6.5421 - accuracy: 0.0402
# Epoch 3/100
# 782/782 [==============================] - 47s 61ms/step - loss: 6.3699 - accuracy: 0.0532
# Epoch 4/100
# 782/782 [==============================] - 47s 61ms/step - loss: 6.1908 - accuracy: 0.0681
# Epoch 5/100
# 782/782 [==============================] - 47s 60ms/step - loss: 6.0285 - accuracy: 0.0786
# Epoch 6/100
# 782/782 [==============================] - 47s 60ms/step - loss: 5.8938 - accuracy: 0.0898
# Epoch 7/100
# 782/782 [==============================] - 47s 60ms/step - loss: 5.7948 - accuracy: 0.0977
# Epoch 8/100
# 782/782 [==============================] - 48s 61ms/step - loss: 5.6965 - accuracy: 0.1031
# Epoch 9/100
# 782/782 [==============================] - 48s 61ms/step - loss: 5.5829 - accuracy: 0.1078
# Epoch 10/100
# 782/782 [==============================] - 47s 60ms/step - loss: 5.5008 - accuracy: 0.1101
# Epoch 11/100
# 782/782 [==============================] - 47s 60ms/step - loss: 5.4080 - accuracy: 0.1138
# Epoch 12/100
# 782/782 [==============================] - 47s 60ms/step - loss: 5.3214 - accuracy: 0.1161
# Epoch 13/100
# 782/782 [==============================] - 47s 60ms/step - loss: 5.2403 - accuracy: 0.1176
# Epoch 14/100
# 782/782 [==============================] - 47s 60ms/step - loss: 5.1530 - accuracy: 0.1205
# Epoch 15/100
# 782/782 [==============================] - 47s 60ms/step - loss: 5.0830 - accuracy: 0.1216
# Epoch 16/100
# 782/782 [==============================] - 46s 59ms/step - loss: 5.0013 - accuracy: 0.1244
# Epoch 17/100
# 782/782 [==============================] - 47s 60ms/step - loss: 4.9185 - accuracy: 0.1277
# Epoch 18/100
# 782/782 [==============================] - 47s 60ms/step - loss: 4.8495 - accuracy: 0.1314
# Epoch 19/100
# 782/782 [==============================] - 47s 60ms/step - loss: 4.7758 - accuracy: 0.1357
# Epoch 20/100
# 782/782 [==============================] - 47s 60ms/step - loss: 4.7067 - accuracy: 0.1416
# Epoch 21/100
# 782/782 [==============================] - 47s 60ms/step - loss: 4.6508 - accuracy: 0.1473
# Epoch 22/100
# 782/782 [==============================] - 47s 60ms/step - loss: 4.5833 - accuracy: 0.1529
# Epoch 23/100
# 782/782 [==============================] - 47s 61ms/step - loss: 4.5431 - accuracy: 0.1574
# Epoch 24/100
# 782/782 [==============================] - 47s 60ms/step - loss: 4.4892 - accuracy: 0.1623
# Epoch 25/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.4367 - accuracy: 0.1686
# Epoch 26/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.3902 - accuracy: 0.1724
# Epoch 27/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.3499 - accuracy: 0.1773
# Epoch 28/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.3070 - accuracy: 0.1812
# Epoch 29/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.2549 - accuracy: 0.1870
# Epoch 30/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.2284 - accuracy: 0.1895
# Epoch 31/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.1909 - accuracy: 0.1945
# Epoch 32/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.1500 - accuracy: 0.2006
# Epoch 33/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.1202 - accuracy: 0.2021
# Epoch 34/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.0848 - accuracy: 0.2062
# Epoch 35/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.0600 - accuracy: 0.2103
# Epoch 36/100
# 782/782 [==============================] - 46s 59ms/step - loss: 4.0229 - accuracy: 0.2152
# Epoch 37/100
# 782/782 [==============================] - 47s 59ms/step - loss: 3.9937 - accuracy: 0.2178
# Epoch 38/100
# 782/782 [==============================] - 47s 59ms/step - loss: 3.9579 - accuracy: 0.2218
# Epoch 39/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.9409 - accuracy: 0.2241
# Epoch 40/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.9036 - accuracy: 0.2299
# Epoch 41/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.8820 - accuracy: 0.2336
# Epoch 42/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.8430 - accuracy: 0.2372
# Epoch 43/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.8176 - accuracy: 0.2417
# Epoch 44/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.8032 - accuracy: 0.2438
# Epoch 45/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.7653 - accuracy: 0.2467
# Epoch 46/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.7440 - accuracy: 0.2502
# Epoch 47/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.7159 - accuracy: 0.2547
# Epoch 48/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.6897 - accuracy: 0.2589
# Epoch 49/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.6662 - accuracy: 0.2595
# Epoch 50/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.6479 - accuracy: 0.2634
# Epoch 51/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.6231 - accuracy: 0.2663
# Epoch 52/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.5904 - accuracy: 0.2706
# Epoch 53/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.5696 - accuracy: 0.2739
# Epoch 54/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.5498 - accuracy: 0.2776
# Epoch 55/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.5240 - accuracy: 0.2811
# Epoch 56/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.5093 - accuracy: 0.2816
# Epoch 57/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.4868 - accuracy: 0.2864
# Epoch 58/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.4597 - accuracy: 0.2891
# Epoch 59/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.4415 - accuracy: 0.2914
# Epoch 60/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.4140 - accuracy: 0.2968
# Epoch 61/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.4036 - accuracy: 0.2979
# Epoch 62/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.3744 - accuracy: 0.3011
# Epoch 63/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.3765 - accuracy: 0.3018
# Epoch 64/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.3323 - accuracy: 0.3094
# Epoch 65/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.3166 - accuracy: 0.3111
# Epoch 66/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.2822 - accuracy: 0.3140
# Epoch 67/100
# 782/782 [==============================] - 46s 59ms/step - loss: 3.2813 - accuracy: 0.3146
# Epoch 68/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.2534 - accuracy: 0.3190
# Epoch 69/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.2332 - accuracy: 0.3224
# Epoch 70/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.2136 - accuracy: 0.3243
# Epoch 71/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.2066 - accuracy: 0.3264
# Epoch 72/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.1818 - accuracy: 0.3312
# Epoch 73/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.1591 - accuracy: 0.3347
# Epoch 74/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.1377 - accuracy: 0.3378
# Epoch 75/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.1178 - accuracy: 0.3401
# Epoch 76/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.1054 - accuracy: 0.3431
# Epoch 77/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.0666 - accuracy: 0.3494
# Epoch 78/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.0651 - accuracy: 0.3485
# Epoch 79/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.0521 - accuracy: 0.3513
# Epoch 80/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.0332 - accuracy: 0.3538
# Epoch 81/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.0035 - accuracy: 0.3605
# Epoch 82/100
# 782/782 [==============================] - 47s 60ms/step - loss: 3.0023 - accuracy: 0.3590
# Epoch 83/100
# 782/782 [==============================] - 47s 60ms/step - loss: 2.9851 - accuracy: 0.3628
# Epoch 84/100
# 782/782 [==============================] - 47s 60ms/step - loss: 2.9652 - accuracy: 0.3644
# Epoch 85/100
# 782/782 [==============================] - 47s 60ms/step - loss: 2.9430 - accuracy: 0.3691
# Epoch 86/100
# 782/782 [==============================] - 47s 60ms/step - loss: 2.9272 - accuracy: 0.3722
# Epoch 87/100
# 782/782 [==============================] - 47s 60ms/step - loss: 2.9031 - accuracy: 0.3758
# Epoch 88/100
# 782/782 [==============================] - 47s 60ms/step - loss: 2.9002 - accuracy: 0.3756
# Epoch 89/100
# 782/782 [==============================] - 47s 61ms/step - loss: 2.8772 - accuracy: 0.3806
# Epoch 90/100
# 782/782 [==============================] - 46s 59ms/step - loss: 2.8658 - accuracy: 0.3838
# Epoch 91/100
# 782/782 [==============================] - 46s 59ms/step - loss: 2.8575 - accuracy: 0.3828
# Epoch 92/100
# 782/782 [==============================] - 47s 60ms/step - loss: 2.8441 - accuracy: 0.3852
# Epoch 93/100
# 782/782 [==============================] - 46s 59ms/step - loss: 2.8150 - accuracy: 0.3900
# Epoch 94/100
# 782/782 [==============================] - 46s 59ms/step - loss: 2.7997 - accuracy: 0.3955
# Epoch 95/100
# 782/782 [==============================] - 46s 59ms/step - loss: 2.7917 - accuracy: 0.3947
# Epoch 96/100
# 782/782 [==============================] - 46s 59ms/step - loss: 2.7771 - accuracy: 0.3970
# Epoch 97/100
# 782/782 [==============================] - 46s 59ms/step - loss: 2.7644 - accuracy: 0.3984
# Epoch 98/100
# 782/782 [==============================] - 46s 59ms/step - loss: 2.7446 - accuracy: 0.4018
# Epoch 99/100
# 782/782 [==============================] - 46s 59ms/step - loss: 2.7333 - accuracy: 0.4029
# Epoch 100/100
# 782/782 [==============================] - 46s 59ms/step - loss: 2.7234 - accuracy: 0.4080
# CPU times: user 49min 49s, sys: 5min 58s, total: 55min 48s
# Wall time: 1h 18min 16s

# %% [markdown]
# 40% accuracy in 1h-20 min

# %%
import matplotlib.pyplot as plt

losses_lstm = model.history.history['loss']
plt.figure(figsize=(12,4))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot(range(len(losses_lstm)),losses_lstm);

# %%
losses_lstm = model.history.history['accuracy']
plt.figure(figsize=(12,4))
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot(range(len(losses_lstm)),losses_lstm);

# %% [markdown]
# We are now going to generate words using the model.
#
# For this we need a set of 50 words to predict the 51st word.
#
# So we are taking a random line.

# %%
model.save('shakespeare_bot.h5')

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/shakespeare.h5
# Out:
# --2021-05-18 18:40:21--  https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/shakespeare.h5
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 52.95.148.46
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|52.95.148.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25437020 (24M) [application/octet-stream]
# Saving to: ‘shakespeare.h5’
#
# shakespeare.h5      100%[===================>]  24.26M  19.6MB/s    in 1.2s
#
# 2021-05-18 18:40:23 (19.6 MB/s) - ‘shakespeare.h5’ saved [25437020/25437020]

# %%
from tensorflow.keras.models import load_model
model = load_model('shakespeare.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 50, 50)            650450
# _________________________________________________________________
# lstm (LSTM)                  (None, 50, 100)           60400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 100)               10100
# _________________________________________________________________
# dense_1 (Dense)              (None, 13009)             1313909
# =================================================================
# Total params: 2,115,259
# Trainable params: 2,115,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
seed_text=lines[12343]
seed_text
# Out:
# 'home of love if i have ranged like him that travels i return again just to the time not with the time exchanged so that my self bring water for my stain never believe though in my nature reigned all frailties that besiege all kinds of blood that it could so'

# %% [markdown]
# generate_text_seq() generates n_words number of words after the given seed_text. We are going to pre-process the seed_text before predicting. We are going to encode the seed_text using the same encoding used for encoding the training data. Then we are going to convert the seed_textto 50 words by using pad_sequences(). Now we will predict using model.predict_classes(). After that we will search the word in tokenizer using the index in y_predict. Finally we will append the predicted word to seed_text and text and repeat the process.

# %%
def generate_text_seq(model, tokenizer, text_seq_length, seed_text, n_words):
  text = []

  for _ in range(n_words):
    encoded = tokenizer.texts_to_sequences([seed_text])[0]
    encoded = pad_sequences([encoded], maxlen = text_seq_length, truncating='pre')

    y_predict = model.predict_classes(encoded)

    predicted_word = ''
    for word, index in tokenizer.word_index.items():
      if index == y_predict:
        predicted_word = word
        break
    seed_text = seed_text + ' ' + predicted_word
    text.append(predicted_word)
  return ' '.join(text)

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/bot.png" width="1200">

# %%
#We can see that the next 100 words are predicted by the model for the seed_text.
text_generated = generate_text_seq(model, tokenizer, seq_length, seed_text, 100)
text_generated

# %% [markdown]
# ## Text To Speech

# %% [markdown]
# Google Text-to-Speech), a Python library and CLI tool to interface with Google Translate's text-to-speech API

# %%
# !pip install gTTS
# Out:
# Collecting gTTS
#   Downloading https://files.pythonhosted.org/packages/5f/b9/94e59337107be134b21ce395a29fc0715b707b560108d6797de2d93e1178/gTTS-2.2.2-py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gTTS) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gTTS) (2.23.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from gTTS) (8.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gTTS) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gTTS) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gTTS) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gTTS) (2.10)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.2.2

# %%
from gtts import gTTS
from IPython.display import Audio
tts = gTTS(text_generated)
tts.save('1.wav')
sound_file = '1.wav'
Audio(sound_file, autoplay=True)

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/tenor.gif" width="350">

# %%
text = 'be or not to be'

text_generated = generate_text_seq(model, tokenizer, seq_length, text, 100)
text_generated
# Out:
# 'made to join with simple weeds for the service of a conquered more breaths i have immortal longings in me and be troubled with him and to make me not a patent for a diadem ever as to be won of love and to shift it tell me not seems to you and to be movd already to yaughan wiser to you avoid hor i would you throw it out of the mart parolles ay madam valeria i thank you for idleness the painful sir i am a strumpet i am about you guard things mend you all joy and'
