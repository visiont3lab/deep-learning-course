# %% [markdown]
# <a href="https://colab.research.google.com/github/visiont3lab/deep-learning-course/blob/main/colab/ExcerciseSineApprox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.graph_objects as go
from torch import nn
from torch.utils.data import DataLoader
from torch import optim
import torch
from torch import nn
from torchsummary import summary
#!pip install torchsummary
import torch.nn.functional as F
from torch.utils.data import TensorDataset,Dataset
from torchvision import datasets
from torchvision import transforms
from sklearn.model_selection import train_test_split
import numpy as np

# Loss function pytorch: https://neptune.ai/blog/pytorch-loss-functions

class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.fc1 = nn.Linear(1,60)
        self.fc2 = nn.Linear(60,40)
        self.fc3 = nn.Linear(40,1)
    def forward(self,x):
        x = torch.tanh(self.fc1(x))
        x = torch.tanh(self.fc2(x))
        x = self.fc3(x)
        return x

class CustomTensorDataset(Dataset):

    def __init__(self, x,y):
        self.x = x
        self.y = y

    def __getitem__(self, index):
        x = self.x[index]
        y = self.y[index]
        return x, y

    def __len__(self):
        return self.x.shape[0]


def metrics_batch(target, output):
    mse = torch.sum((output - target) ** 2)
    return mse

def loss_batch(loss_func, xb,yb,yb_h, opt=None):
    # obtain loss
    loss = loss_func(yb_h, yb)
    # obtain permormance metric 
    metric_b = metrics_batch(yb,yb_h)
    if opt is not None:
        loss.backward()
        opt.step()
        opt.zero_grad()
    return loss.item(), metric_b

def loss_epoch(model, loss_func, dataset_dl, opt,device):
    loss = 0.0
    metric = 0.0
    len_data = len(dataset_dl.dataset)

    # Get batch data
    for xb,yb in dataset_dl:    
        # Send to cuda the data (batch size)
        xb = xb.type(torch.float32).to(device)
        yb = yb.to(device)

        # obtain model output 
        yb_h = model(xb)

        # Loss and Metric Calculation
        loss_b, metric_b = loss_batch(loss_func, xb,yb,yb_h,opt)
        loss += loss_b
        if metric_b is not None:
            metric+=metric_b 
    
    loss /=len_data
    metric /=len_data
    return loss, metric

def train_val(epochs, model, loss_func, opt, train_dl,val_dl,device):
    for epoch in range(epochs):
        model.train()
        train_loss,train_metric = loss_epoch(model, loss_func, train_dl, opt,device)
        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl,opt=None,device=device)
        accuracy = 100*val_metric
        print("epoch: %d, train_loss: %.6f, val loss: %.6f, accuracy: %.2f" % (epoch,train_loss, val_loss,accuracy))

# Setup GPU Device
device = torch.device("cpu")
if torch.cuda.is_available():
    device = torch.device("cuda:0")

# Load and Preprocess data 
x = 1*np.linspace(-2,3,6000)
y = np.sin(5*x)
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.33, random_state=4)
x_train = torch.from_numpy(x_train).unsqueeze(1).type(torch.float32)
y_train = torch.from_numpy(y_train).unsqueeze(1).type(torch.float32)
x_val = torch.from_numpy(x_val).unsqueeze(1).type(torch.float32)
y_val = torch.from_numpy(y_val).unsqueeze(1).type(torch.float32)

# Transformation
train_ds = CustomTensorDataset(x_train, y_train)
val_ds = CustomTensorDataset(x_val, y_val)

# Create Data loader
train_dl = DataLoader(train_ds, batch_size=50)
val_dl = DataLoader(val_ds, batch_size=50)

# Define Model, Loss , Optimizer
model = Net()
model.to(device)
#print(model)
# By default model is hosted on CPU
print("Model Parameter Device: ", next(model.parameters()).device)
summary(model, input_size=tuple(x_train.shape))
loss_func = nn.MSELoss(reduction="sum") 
opt = optim.Adam(model.parameters(), lr=1e-2)

# Train
num_epochs = 100
train_val(num_epochs,model, loss_func,opt, train_dl, val_dl,device)

# Save Models (It save last weights)
path2weigths="./weights.pt"
torch.save(model.state_dict(),path2weigths)
# Out:
# Model Parameter Device:  cpu
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1             [-1, 4020, 60]             120
#             Linear-2             [-1, 4020, 40]           2,440
#             Linear-3              [-1, 4020, 1]              41
# ================================================================
# Total params: 2,601
# Trainable params: 2,601
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 3.10
# Params size (MB): 0.01
# Estimated Total Size (MB): 3.12
# ----------------------------------------------------------------
# epoch: 0, train_loss: 0.502121, val loss: 0.500059, accuracy: 50.01
# epoch: 1, train_loss: 0.457991, val loss: 0.445913, accuracy: 44.59
# epoch: 2, train_loss: 0.378062, val loss: 0.377292, accuracy: 37.73
# epoch: 3, train_loss: 0.292343, val loss: 0.295579, accuracy: 29.56
# epoch: 4, train_loss: 0.213137, val loss: 0.175530, accuracy: 17.55
# epoch: 5, train_loss: 0.089350, val loss: 0.044093, accuracy: 4.41
# epoch: 6, train_loss: 0.034429, val loss: 0.025970, accuracy: 2.60
# epoch: 7, train_loss: 0.028071, val loss: 0.020909, accuracy: 2.09
# epoch: 8, train_loss: 0.013590, val loss: 0.004504, accuracy: 0.45
# epoch: 9, train_loss: 0.003382, val loss: 0.002218, accuracy: 0.22
# epoch: 10, train_loss: 0.002449, val loss: 0.001789, accuracy: 0.18
# epoch: 11, train_loss: 0.002371, val loss: 0.001913, accuracy: 0.19
# epoch: 12, train_loss: 0.002501, val loss: 0.002435, accuracy: 0.24
# epoch: 13, train_loss: 0.002710, val loss: 0.003370, accuracy: 0.34
# epoch: 14, train_loss: 0.002879, val loss: 0.004050, accuracy: 0.40
# epoch: 15, train_loss: 0.002948, val loss: 0.004234, accuracy: 0.42
# epoch: 16, train_loss: 0.002948, val loss: 0.004241, accuracy: 0.42
# epoch: 17, train_loss: 0.002936, val loss: 0.004148, accuracy: 0.41
# epoch: 18, train_loss: 0.002907, val loss: 0.003934, accuracy: 0.39
# epoch: 19, train_loss: 0.002834, val loss: 0.003555, accuracy: 0.36
# epoch: 20, train_loss: 0.002719, val loss: 0.002989, accuracy: 0.30
# epoch: 21, train_loss: 0.002582, val loss: 0.002381, accuracy: 0.24
# epoch: 22, train_loss: 0.002433, val loss: 0.002125, accuracy: 0.21
# epoch: 23, train_loss: 0.002419, val loss: 0.002529, accuracy: 0.25
# epoch: 24, train_loss: 0.002556, val loss: 0.002961, accuracy: 0.30
# epoch: 25, train_loss: 0.002641, val loss: 0.002853, accuracy: 0.29
# epoch: 26, train_loss: 0.002592, val loss: 0.002526, accuracy: 0.25
# epoch: 27, train_loss: 0.002597, val loss: 0.002367, accuracy: 0.24
# epoch: 28, train_loss: 0.002635, val loss: 0.002355, accuracy: 0.24
# epoch: 29, train_loss: 0.002613, val loss: 0.002407, accuracy: 0.24
# epoch: 30, train_loss: 0.002528, val loss: 0.002448, accuracy: 0.24
# epoch: 31, train_loss: 0.002436, val loss: 0.002573, accuracy: 0.26
# epoch: 32, train_loss: 0.002421, val loss: 0.002996, accuracy: 0.30
# epoch: 33, train_loss: 0.002656, val loss: 0.003625, accuracy: 0.36
# epoch: 34, train_loss: 0.003228, val loss: 0.002667, accuracy: 0.27
# epoch: 35, train_loss: 0.002233, val loss: 0.001905, accuracy: 0.19
# epoch: 36, train_loss: 0.002258, val loss: 0.003057, accuracy: 0.31
# epoch: 37, train_loss: 0.002332, val loss: 0.001566, accuracy: 0.16
# epoch: 38, train_loss: 0.001843, val loss: 0.002115, accuracy: 0.21
# epoch: 39, train_loss: 0.001686, val loss: 0.001419, accuracy: 0.14
# epoch: 40, train_loss: 0.002134, val loss: 0.002874, accuracy: 0.29
# epoch: 41, train_loss: 0.001402, val loss: 0.000915, accuracy: 0.09
# epoch: 42, train_loss: 0.001297, val loss: 0.001277, accuracy: 0.13
# epoch: 43, train_loss: 0.001199, val loss: 0.002741, accuracy: 0.27
# epoch: 44, train_loss: 0.001382, val loss: 0.011681, accuracy: 1.17
# epoch: 45, train_loss: 0.002080, val loss: 0.003822, accuracy: 0.38
# epoch: 46, train_loss: 0.002321, val loss: 0.026893, accuracy: 2.69
# epoch: 47, train_loss: 0.003659, val loss: 0.001266, accuracy: 0.13
# epoch: 48, train_loss: 0.002367, val loss: 0.008044, accuracy: 0.80
# epoch: 49, train_loss: 0.003042, val loss: 0.002466, accuracy: 0.25
# epoch: 50, train_loss: 0.001117, val loss: 0.003015, accuracy: 0.30
# epoch: 51, train_loss: 0.001658, val loss: 0.002342, accuracy: 0.23
# epoch: 52, train_loss: 0.001289, val loss: 0.004591, accuracy: 0.46
# epoch: 53, train_loss: 0.001561, val loss: 0.002541, accuracy: 0.25
# epoch: 54, train_loss: 0.001595, val loss: 0.004254, accuracy: 0.43
# epoch: 55, train_loss: 0.001773, val loss: 0.003496, accuracy: 0.35
# epoch: 56, train_loss: 0.001920, val loss: 0.004368, accuracy: 0.44
# epoch: 57, train_loss: 0.001686, val loss: 0.004460, accuracy: 0.45
# epoch: 58, train_loss: 0.001925, val loss: 0.004754, accuracy: 0.48
# epoch: 59, train_loss: 0.001666, val loss: 0.005452, accuracy: 0.55
# epoch: 60, train_loss: 0.001733, val loss: 0.005740, accuracy: 0.57
# epoch: 61, train_loss: 0.001775, val loss: 0.004975, accuracy: 0.50
# epoch: 62, train_loss: 0.001635, val loss: 0.013116, accuracy: 1.31
# epoch: 63, train_loss: 0.002259, val loss: 0.002604, accuracy: 0.26
# epoch: 64, train_loss: 0.001697, val loss: 0.001354, accuracy: 0.14
# epoch: 65, train_loss: 0.001335, val loss: 0.003011, accuracy: 0.30
# epoch: 66, train_loss: 0.003459, val loss: 0.043290, accuracy: 4.33
# epoch: 67, train_loss: 0.012783, val loss: 0.012997, accuracy: 1.30
# epoch: 68, train_loss: 0.008704, val loss: 0.003497, accuracy: 0.35
# epoch: 69, train_loss: 0.001694, val loss: 0.000725, accuracy: 0.07
# epoch: 70, train_loss: 0.001264, val loss: 0.000801, accuracy: 0.08
# epoch: 71, train_loss: 0.001280, val loss: 0.000840, accuracy: 0.08
# epoch: 72, train_loss: 0.000875, val loss: 0.000603, accuracy: 0.06
# epoch: 73, train_loss: 0.000757, val loss: 0.000806, accuracy: 0.08
# epoch: 74, train_loss: 0.000976, val loss: 0.001758, accuracy: 0.18
# epoch: 75, train_loss: 0.001300, val loss: 0.002873, accuracy: 0.29
# epoch: 76, train_loss: 0.001347, val loss: 0.005198, accuracy: 0.52
# epoch: 77, train_loss: 0.001660, val loss: 0.007311, accuracy: 0.73
# epoch: 78, train_loss: 0.002169, val loss: 0.006728, accuracy: 0.67
# epoch: 79, train_loss: 0.002073, val loss: 0.007918, accuracy: 0.79
# epoch: 80, train_loss: 0.001948, val loss: 0.007716, accuracy: 0.77
# epoch: 81, train_loss: 0.001760, val loss: 0.007417, accuracy: 0.74
# epoch: 82, train_loss: 0.001630, val loss: 0.007685, accuracy: 0.77
# epoch: 83, train_loss: 0.001681, val loss: 0.007730, accuracy: 0.77
# epoch: 84, train_loss: 0.001899, val loss: 0.008873, accuracy: 0.89
# epoch: 85, train_loss: 0.002190, val loss: 0.009166, accuracy: 0.92
# epoch: 86, train_loss: 0.002225, val loss: 0.010837, accuracy: 1.08
# epoch: 87, train_loss: 0.001800, val loss: 0.006738, accuracy: 0.67
# epoch: 88, train_loss: 0.001561, val loss: 0.009721, accuracy: 0.97
# epoch: 89, train_loss: 0.001716, val loss: 0.003901, accuracy: 0.39
# epoch: 90, train_loss: 0.001590, val loss: 0.008221, accuracy: 0.82
# epoch: 91, train_loss: 0.002171, val loss: 0.006829, accuracy: 0.68
# epoch: 92, train_loss: 0.003319, val loss: 0.006962, accuracy: 0.70
# epoch: 93, train_loss: 0.001417, val loss: 0.007290, accuracy: 0.73
# epoch: 94, train_loss: 0.001602, val loss: 0.006428, accuracy: 0.64
# epoch: 95, train_loss: 0.002006, val loss: 0.004109, accuracy: 0.41
# epoch: 96, train_loss: 0.001254, val loss: 0.003510, accuracy: 0.35
# epoch: 97, train_loss: 0.001211, val loss: 0.007352, accuracy: 0.74
# epoch: 98, train_loss: 0.001639, val loss: 0.004121, accuracy: 0.41
# epoch: 99, train_loss: 0.002066, val loss: 0.004017, accuracy: 0.40

# %%
# Data 
x = 1*np.linspace(-5,6,6000)
y = np.sin(5*x)

# Model Trained Load
md = Net()
weights = torch.load(path2weigths)
md.load_state_dict(weights)
device = torch.device("cpu")
md = md.to(device)
#print(next(md.parameters()))

y_hat_vec = md(torch.from_numpy(x).unsqueeze(1).type(torch.float32))
y_hat_vec = y_hat_vec.detach().numpy()
y_hat_vec = y_hat_vec.reshape(-1)


# Deploy
fig = go.Figure()
fig.add_traces( go.Scatter(x=x, y=y, name="Real"))
fig.add_traces( go.Scatter(x=x, y=y_hat_vec, name="Estimate"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c7f35d18-a249-4e76-ac42-1b7e6d69f6a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7f35d18-a249-4e76-ac42-1b7e6d69f6a2")) {                    Plotly.newPlot(                        "c7f35d18-a249-4e76-ac42-1b7e6d69f6a2",                        [{"name":"Real","x":[-5.0,-4.998166361060177,-4.9963327221203535,-4.99449908318053,-4.992665444240707,-4.990831805300884,-4.9889981663610605,-4.987164527421237,-4.985330888481413,-4.98349724954159,-4.981663610601767,-4.979829971661943,-4.97799633272212,-4.976162693782297,-4.974329054842474,-4.97249541590265,-4.970661776962827,-4.968828138023004,-4.966994499083181,-4.9651608601433574,-4.963327221203534,-4.961493582263711,-4.959659943323888,-4.957826304384064,-4.95599266544424,-4.954159026504417,-4.952325387564594,-4.950491748624771,-4.948658109684947,-4.946824470745124,-4.944990831805301,-4.943157192865478,-4.941323553925654,-4.939489914985831,-4.937656276046008,-4.935822637106185,-4.933988998166361,-4.932155359226538,-4.930321720286715,-4.928488081346891,-4.9266544424070675,-4.924820803467244,-4.922987164527421,-4.921153525587598,-4.9193198866477745,-4.917486247707951,-4.915652608768128,-4.913818969828305,-4.9119853308884815,-4.910151691948658,-4.908318053008835,-4.906484414069012,-4.904650775129189,-4.902817136189365,-4.900983497249541,-4.899149858309718,-4.897316219369895,-4.8954825804300715,-4.893648941490248,-4.891815302550425,-4.889981663610602,-4.8881480246707785,-4.886314385730955,-4.884480746791132,-4.882647107851309,-4.8808134689114855,-4.878979829971662,-4.877146191031839,-4.875312552092016,-4.873478913152192,-4.871645274212368,-4.869811635272545,-4.867977996332722,-4.866144357392899,-4.864310718453075,-4.862477079513252,-4.860643440573429,-4.858809801633606,-4.856976162693782,-4.855142523753959,-4.853308884814136,-4.851475245874313,-4.849641606934489,-4.847807967994666,-4.845974329054842,-4.844140690115019,-4.8423070511751956,-4.840473412235372,-4.838639773295549,-4.836806134355726,-4.834972495415903,-4.833138856476079,-4.831305217536256,-4.829471578596433,-4.82763793965661,-4.825804300716786,-4.823970661776963,-4.82213702283714,-4.820303383897317,-4.818469744957493,-4.816636106017669,-4.814802467077846,-4.812968828138023,-4.8111351891981995,-4.809301550258376,-4.807467911318553,-4.80563427237873,-4.8038006334389065,-4.801966994499083,-4.80013335555926,-4.798299716619437,-4.7964660776796135,-4.79463243873979,-4.792798799799967,-4.790965160860143,-4.78913152192032,-4.787297882980496,-4.785464244040673,-4.78363060510085,-4.781796966161027,-4.779963327221203,-4.77812968828138,-4.776296049341557,-4.774462410401734,-4.7726287714619104,-4.770795132522087,-4.768961493582264,-4.767127854642441,-4.7652942157026175,-4.763460576762794,-4.76162693782297,-4.759793298883147,-4.757959659943324,-4.7561260210035,-4.754292382063677,-4.752458743123854,-4.750625104184031,-4.748791465244207,-4.746957826304384,-4.745124187364561,-4.743290548424738,-4.741456909484914,-4.739623270545091,-4.737789631605268,-4.735955992665445,-4.7341223537256205,-4.732288714785797,-4.730455075845974,-4.728621436906151,-4.7267877979663275,-4.724954159026504,-4.723120520086681,-4.721286881146858,-4.7194532422070345,-4.717619603267211,-4.715785964327388,-4.713952325387565,-4.712118686447742,-4.710285047507918,-4.708451408568095,-4.706617769628272,-4.704784130688448,-4.7029504917486245,-4.701116852808801,-4.699283213868978,-4.697449574929155,-4.6956159359893315,-4.693782297049508,-4.691948658109685,-4.690115019169862,-4.6882813802300385,-4.686447741290215,-4.684614102350392,-4.682780463410569,-4.6809468244707455,-4.679113185530921,-4.677279546591098,-4.675445907651275,-4.673612268711452,-4.671778629771628,-4.669944990831805,-4 ...
